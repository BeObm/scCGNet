# %%
from pathlib import Path
from typing import Optional, Tuple

import h5py
import numpy as np
import scanpy as sc
import scipy.sparse as sp
from sklearn.preprocessing import LabelEncoder

# %%
for fi in ["data/10X_PBMC.h5","data/human_kidney_counts.h5","data/human_kidney_counts.h5","data/Mouse.h5","data/mouse_ES.h5",
           "data/Quake_10x_Bladder.h5","data/Quake_Smart-seq2_Limb_Muscle.h5","data/Quake_Smart-seq2_Trachea.h5",
           "data/Quake_Smart-seq2_Trachea.h5","data/Zeisel.h5"]:
    with h5py.File(fi) as f:
        print(list(f.keys()))
# Out:
# ['X', 'Y']
# ['X', 'Y']
# ['X', 'Y']
# ['X', 'Y']
# ['X', 'Y']
# ['exprs', 'obs', 'obs_names', 'uns', 'var', 'var_names']
# ['exprs', 'obs', 'obs_names', 'uns', 'var', 'var_names']
# ['exprs', 'obs', 'obs_names', 'uns', 'var', 'var_names']
# ['exprs', 'obs', 'obs_names', 'uns', 'var', 'var_names']
# ['X', 'obs', 'obsm', 'raw.X', 'raw.var', 'uns', 'var', 'varm']
